# %% [markdown]
# <a href="https://colab.research.google.com/github/SaadArqam/Supernan-Dubber/blob/main/supernan_dubber.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !git clone https://github.com/SaadArqam/supernan-dubber.git
# %cd supernan-dubber

# %%
# !cd /content/supernan-dubber && git reset --hard && git pull origin main

# %%
# !pip install faster-whisper transformers accelerate scipy
# !pip install edge-tts

# %%
# %cd /content/supernan-dubber
# !python dub_video.py

# %%
from google.colab import files

print("\nDownloading final video...")
files.download("dubbed_output.mp4")
